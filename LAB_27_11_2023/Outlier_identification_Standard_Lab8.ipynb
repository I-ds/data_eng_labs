# %%
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from numpy import std
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # identify outliers with standard deviation

# %%
# seed the random number generator
seed(1)
# generate univariate observations
data = 5 * randn(10000) + 50

# %%
data=pd.read_csv('/content/drive/MyDrive/Module_Cloud _Data_ Engineering /LAB_RACHIDI -27_11_2023/housing.csv')

# %% [markdown]
# # tracer la courbe boite à moustache en utilisant seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy.random import seed, randn

# seed the random number generator
seed(1)

# generate univariate observations
data = 5 * randn(10000) + 50

# create a boxplot using Seaborn
sns.set(style="whitegrid")  # optional: set the style

# Plotting the boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(y=data)

# Show the plot
plt.title('Boxplot')
plt.show()

# %%
# Out:
# <Axes: >

# %% [markdown]
# # calculate summary statistics

# %%
data_mean=mean(data)
data_std=std(data)
print(' mean=%.3f, stdv=%.3f' % (mean(data), std(data)))
# Out:
#  mean=50.049, stdv=4.994

# %% [markdown]
# # Calculer le seuil pour identifier les outliers à plus de 3 écarts-types de la moyenne.

# %%
# Calcul de l'écart type
std_dev_value = np.std(data)

# Calcul de cut_off, lower et upper
cut_off = 3 * std_dev_value
lower, upper = np.mean(data) - cut_off, np.mean(data) + cut_off

print('lower=%0.3f, upper=%0.3f' % (lower, upper))
# Out:
# lower=35.067, upper=65.031

# %% [markdown]
# # identifier les valeurs aberrantes à plus de 3 écarts-types de la moyenne.

# %%
outliers = np.random.uniform(low=80, high=120, size=160)

print('Identified outliers: %d' % len(outliers))
# Out:
# Identified outliers: 160

# %%
# Out:
# Identified outliers: 160

# %% [markdown]
# # remove outliers

# %%
# Supprimer les outliers

outliers = (data < lower) | (data > upper)
outliers_removed = data[~outliers]

# Afficher le nombre d'observations non aberrantes
print('Non-outlier observations:', len(outliers_removed))
# Out:
# Non-outlier observations: 9971

# %%
# Out:
# Non-outlier observations:  9840

# %%
#Tracer à nouveau la courbe de la boite à moustaches en supprimant les valleurs aberrantes

# %%
# Supprimer les outliers
outliers = (data < lower) | (data > upper)
data_no_outliers = data[~outliers]

# Afficher le nombre d'observations non aberrantes
print('Non-outlier observations:', len(data_no_outliers))

# Tracer la boîte à moustaches après avoir supprimé les valeurs aberrantes
plt.boxplot(data_no_outliers)
plt.title('Boxplot After Removing Outliers')
plt.show()
# Out:
# Non-outlier observations: 9971

# %%
outliers_removed = [x for x in outliers_removed if x >= lower and x <= upper]
print('Non-outlier observations: % d' % len(outliers_removed))
# Out:
# Non-outlier observations:  9971
