# %% [markdown]
#  # Identifier les lignes qui contiennent des données en double

# %% [markdown]
#  - Les lignes qui contiennent des données identiques peuvent être inutiles auprocessus de modélisation, voire dangereusement trompeuses lors de l’évaluation du modèle.
# - Ici, une ligne dupliquée est une ligne où chaque valeur de chaque colonne de ette ligne apparaît dans le même ordre dans une autre ligne.
#
# - La fonction duplicated() de Pandas indique si une ligne donnée est dupliquée ou non.

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# locate rows of duplicate data
from pandas import read_csv
# load the dataset
df = read_csv('/content/drive/MyDrive/Module_Cloud _Data_ Engineering /LAB-27_11_2023/iris.csv',header=None)
# calculate duplicates
dups = df.duplicated()
# report if there are any duplicates
print("vérification si une ligne donnée est dupliquée ou non")
print("reponsse :",dups.any())
# list all duplicate rows
print("list all duplicate rows")
print(df[dups])
# Out:
# vérification si une ligne donnée est dupliquée ou non
# reponsse : True
# list all duplicate rows
#        0    1    2    3               4
# 34   4.9  3.1  1.5  0.1     Iris-setosa
# 37   4.9  3.1  1.5  0.1     Iris-setosa
# 142  5.8  2.7  5.1  1.9  Iris-virginica

# %%
#keep (facultatif) : Contrôle le comportement de marquage des doublons. Il peut prendre trois valeurs :

#first : Marque toutes les occurrences de duplicatas, sauf la première.
#last : Marque toutes les occurrences de duplicatas, sauf la dernière.
ups = df.duplicated(keep='last')
# Afficher les doublons
print(df[dups])
dups = df.duplicated(keep='first')
print(df[dups])
# Out:
#        0    1    2    3               4
# 34   4.9  3.1  1.5  0.1     Iris-setosa
# 37   4.9  3.1  1.5  0.1     Iris-setosa
# 142  5.8  2.7  5.1  1.9  Iris-virginica
#        0    1    2    3               4
# 34   4.9  3.1  1.5  0.1     Iris-setosa
# 37   4.9  3.1  1.5  0.1     Iris-setosa
# 142  5.8  2.7  5.1  1.9  Iris-virginica

# %% [markdown]
# - Découvrir les arguments de la méthode duplicated() et les expliquer en faisant des tests

# %% [markdown]
# # Supprimer les lignes qui contiennent des données en double

# %% [markdown]
# - Les lignes de données en double doivent probablement être supprimées de votre ensemble de données avant la modélisation.
# - Il existe de nombreuses façons d’y parvenir, mais Pandas fournit la fonction drop_duplicates() qui permet de supprimer la ligne dupliquée

# %%
# Supprimer les lignes en double du DataFrame (df)
data_no_duplicates = df.drop_duplicates()

# Afficher le DataFrame sans les lignes en double
print(data_no_duplicates)
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
# Out:
# (150, 5)
# (147, 5)
